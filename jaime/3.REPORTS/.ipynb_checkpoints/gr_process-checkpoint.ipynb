# %%
import pandas as pd
import datetime as dt
import gradio as gr

# %%
import warnings 
pd.options.mode.chained_assignment = None # se desactiva advertencias de pandas por la edición_sobrescritura

# %%
# Lectura manual
df1=pd.read_parquet("../data/Automated_Traffic_Volume_Counts.parquet")

air_quality=pd.read_csv("../data/finale_dataset/air_pollution.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [9], line 2
#       1 # Lectura manual
# ----> 2 df1=pd.read_parquet("../data/Automated_Traffic_Volume_Counts.parquet")
#       4 air_quality=pd.read_csv("../data/finale_dataset/air_pollution.csv")
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parquet.py:493, in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, **kwargs)
#     446 """
#     447 Load a parquet object from the file path, returning a DataFrame.
#     448
#    (...)
#     489 DataFrame
#     490 """
#     491 impl = get_engine(engine)
# --> 493 return impl.read(
#     494     path,
#     495     columns=columns,
#     496     storage_options=storage_options,
#     497     use_nullable_dtypes=use_nullable_dtypes,
#     498     **kwargs,
#     499 )
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parquet.py:233, in PyArrowImpl.read(self, path, columns, use_nullable_dtypes, storage_options, **kwargs)
#     230 if manager == "array":
#     231     to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
# --> 233 path_or_handle, handles, kwargs["filesystem"] = _get_path_or_handle(
#     234     path,
#     235     kwargs.pop("filesystem", None),
#     236     storage_options=storage_options,
#     237     mode="rb",
#     238 )
#     239 try:
#     240     result = self.api.parquet.read_table(
#     241         path_or_handle, columns=columns, **kwargs
#     242     ).to_pandas(**to_pandas_kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parquet.py:102, in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#      92 handles = None
#      93 if (
#      94     not fs
#      95     and not is_dir
#    (...)
#     100     # fsspec resources can also point to directories
#     101     # this branch is used for example when reading from non-fsspec URLs
# --> 102     handles = get_handle(
#     103         path_or_handle, mode, is_text=False, storage_options=storage_options
#     104     )
#     105     fs = None
#     106     path_or_handle = handles.handle
#
# File C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py:795, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#    (...)
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
# --> 795         handle = open(handle, ioargs.mode)
#     796     handles.append(handle)
#     798 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../data/Automated_Traffic_Volume_Counts.parquet'

# %%
air_quality=air_quality[air_quality['polluting_agent'] == 'PM 2.5 (µg/cm3)'].reset_index()

# %%
air_quality.groupby(['borough_name'])['data_value'].mean().reset_index()
# Out:
#     borough_name  data_value
# 0          bronx    9.709606
# 1       brooklyn    9.263040
# 2      manhattan   10.874167
# 3         queens    8.929167
# 4  staten island    8.486759

# %%
vehicular_volume
# Out:
#              date  id_borough   borough_name      volume
# 0      2008-03-10           3         queens  169.092233
# 1      2008-03-10           5  staten island  399.421053
# 2      2008-03-11           3         queens  124.629902
# 3      2008-03-11           5  staten island  335.104167
# 4      2008-03-12           3         queens  102.526961
# ...           ...         ...            ...         ...
# 13016  2020-11-18           3         queens   54.967903
# 13017  2020-11-19           3         queens   54.901338
# 13018  2020-11-20           3         queens   61.222529
# 13019  2020-11-21           3         queens   53.439159
# 13020  2020-11-22           3         queens   43.843197
#
# [13021 rows x 4 columns]

# %%
vehicular_volume=vehicular_volume[['date','borough_name','volume']]
vehicular_volume
# Out:
#              date   borough_name      volume
# 0      2008-03-10         queens  169.092233
# 1      2008-03-10  staten island  399.421053
# 2      2008-03-11         queens  124.629902
# 3      2008-03-11  staten island  335.104167
# 4      2008-03-12         queens  102.526961
# ...           ...            ...         ...
# 13016  2020-11-18         queens   54.967903
# 13017  2020-11-19         queens   54.901338
# 13018  2020-11-20         queens   61.222529
# 13019  2020-11-21         queens   53.439159
# 13020  2020-11-22         queens   43.843197
#
# [13021 rows x 3 columns]

# %%
saf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [8], line 1
# ----> 1 saf
#
# NameError: name 'saf' is not defined

# %%
vehicular_volume=vehicular_volume[['date','borough_name','volume']]
#vehicular_volume['date']=pd.to_datetime(vehicular_volume['date']).dt.year
vehicular_volume=vehicular_volume.groupby(['borough_name']).volume.mean().reset_index()
vehicular_volume

# %%
def kpi_brooklyn(carros):
    
    volume_brooklyn = 97 * 4 * 24
    pm_brooklyn = 9.3
    pm_brooklyn_cars=pm_brooklyn*0.05
    
    
    
    pm_corre_brooklyn = (carros * (pm_brooklyn_cars * 0.35)) / volume_brooklyn
    
    disminuye_brooklyn = (pm_brooklyn_cars - pm_corre_brooklyn)/pm_brooklyn_cars
    
    brooklyn=round(-100*disminuye_brooklyn,2)
    
    return brooklyn

kpi_brooklyn(50)

# %%
def kpi_brooklyn(carros):
    
    volume_brooklyn = 97 * 4 * 24
    pm_brooklyn = 9.3
    OMS = 5
    meta_OMS_brooklyn = (OMS - pm_brooklyn)/OMS
    pm_corre_brooklyn = (carros * (pm_brooklyn * 0.35)) / volume_brooklyn
    disminuye_brooklyn = pm_brooklyn - pm_corre_brooklyn
    metacorre_brooklyn = (OMS - disminuye_brooklyn) / OMS
    pctje_brooklyn = (metacorre_brooklyn - meta_OMS_brooklyn) / meta_OMS_brooklyn
    brooklyn=round(-100*pctje_brooklyn,2)
    
    return brooklyn

def kpi_manhattan(carros):
    volume_manhattan = 135 * 4 * 24
    pm_manhattan = 11
    OMS = 5
    meta_OMS_manhattan = (OMS - pm_manhattan) / OMS
    pm_corre_manhattan = (carros * (pm_manhattan * 0.35)) / volume_manhattan
    disminuye_manhattan = pm_manhattan - pm_corre_manhattan
    metacorre_manhattan = (OMS - disminuye_manhattan) / OMS
    pctje_manhattan = (metacorre_manhattan - meta_OMS_manhattan) / meta_OMS_manhattan
    manhattan=round(-100*pctje_manhattan,2)
    
    return manhattan

def kpi_queen(carros):
    volume_queen = 99 * 4 * 24
    pm_queen = 9
    OMS = 5
    meta_OMS_queen = (OMS - pm_queen) / OMS
    pm_corre_queen = (carros * (pm_queen * 0.35)) / volume_queen
    disminuye_queen = pm_queen - pm_corre_queen
    metacorre_queen = (OMS - disminuye_queen) / OMS
    pctje_queen = (metacorre_queen - meta_OMS_queen) / meta_OMS_queen
    queen=round(-100*pctje_queen,2)
    
    return queen

def kpi_staten_island(carros):
    volume_staten_island = 83 * 4 * 24
    pm_staten_island = 8
    OMS = 5
    meta_OMS_staten_island = (OMS - pm_staten_island) / OMS
    pm_corre_staten_island = (carros * (pm_staten_island * 0.35)) / volume_staten_island
    disminuye_staten_island = pm_staten_island - pm_corre_staten_island
    metacorre_staten_island = (OMS - disminuye_staten_island) /OMS
    pctje_staten_island = (metacorre_staten_island - meta_OMS_staten_island) / meta_OMS_staten_island
    staten_island=round(-100*pctje_staten_island,2)
    
    return staten_island

def kpi_the_bronx(carros):
    volume_the_bronx = 132 * 4 * 24
    pm_the_bronx = 9.7
    OMS = 5
    meta_OMS_the_bronx = (OMS - pm_the_bronx) / OMS
    pm_corre_the_bronx = (carros * (pm_the_bronx * 0.35)) / volume_the_bronx
    disminuye_the_bronx = pm_the_bronx - pm_corre_the_bronx
    metacorre_the_bronx = (OMS - disminuye_the_bronx) /OMS
    pctje_the_bronx = (metacorre_the_bronx - meta_OMS_the_bronx) / meta_OMS_the_bronx
    the_bronx= round(-100*pctje_the_bronx,2)
    
    return the_bronx

def calcular_kpis(carros):
    kpi_b = kpi_brooklyn(carros)
    kpi_m = kpi_manhattan(carros)
    kpi_q = kpi_queen(carros)
    kpi_s = kpi_staten_island(carros)
    kpi_bx= kpi_the_bronx(carros)
    
    indicador=f" {int(carros)} carros eléctricos generan un % de avance hacia la meta establecida por la OMS de: |Brooklyn {kpi_b}% | Manhattan {kpi_m}% |Quenns {kpi_q}% | Staten Islands {kpi_s}% |Bronx {kpi_bx}% |"
    return indicador

# %%
calcular_kpis(3)

# %%
import gradio as gr

title = "REPORTE MEDIOAMBIENTAL"

table_html = """
   <table>
  <tr>
    <th>borough</th>
    <th>PM</th>
    <th>Meta</th>
    <th>% Disminución para el objetivo</th>
  </tr>
  <tr>
    <td>brooklyn</td>
    <td>9,3</td>
    <td>5</td>
    <td>-85</td>
  </tr>
  <tr>
    <td>manhattan</td>
    <td>10,9</td>
    <td>5</td>
    <td>-117</td>
  </tr>
  <tr>
    <td>queens</td>
    <td>8,9</td>
    <td>5</td>
    <td>-79</td>
  </tr>
  <tr>
    <td>staten_island</td>
    <td>8,5</td>
    <td>5</td>
    <td>-70</td>
  </tr>
  <tr>
    <td>the_bronx</td>
    <td>9,7</td>
    <td>5</td>
    <td>-94</td>
  </tr>
</table>
"""

with gr.Blocks(title=title) as demo:
    text = gr.components.HTML("""
        <h1>Indicadores Ambientales</h1>
        <h2>Contaminacón al aire</h2>
        <p> La OMS ha establecido un límite de 5µg/cm3 de PM 2.5 Promedio al año. Las ciudades  deberán adoptar políticas y estrategias
        para alcanzar esta meta. Los Boroughs de NYC cuentan con la siguiente distribución de material particulado. <br>
        
        """ + table_html + """
        
       Se genera un indicador clave de rendimiento que estipula el Porcentaje de Avance a la meta proyectada por la OMS en función 
       al número de vehículos eléctricos en una flota de automóviles que transporten pasajeros en un año.<br>

       <b> KPI: Valor Porcentual de Avance a Meta OMS por # de Autos Eléctricos </b>
        
        </p>
    """)
    
    vehiculos_electricos = gr.Number(label="Numero de Vehículos Electricos en la Flota")
    calcular_btn = gr.Button("% Avance a la Meta per # Vehículos Eléctricos:")
    indicador = gr.Textbox(label = "Indicadores:")
    
    calcular_btn.click(fn=calcular_kpis, inputs=[vehiculos_electricos], outputs=[indicador])
    

demo.launch(share=True)
